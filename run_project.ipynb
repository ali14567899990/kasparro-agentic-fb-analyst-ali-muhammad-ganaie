# %%
import os
os.chdir(r"C:\Users\ALI MUHAMMAD\Desktop\kasparro_project")
os.getcwd()
# Out:
# 'C:\\Users\\ALI MUHAMMAD\\Desktop\\kasparro_project'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ALI MUHAMMAD\\Desktop\\kasparro_project'

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '.venv',
#  'anaconda_projects',
#  'config',
#  'data',
#  'logs',
#  'prompts',
#  'reports',
#  'requirements.txt.txt',
#  'run_project.ipynb',
#  'src']

# %%
os.listdir("src")
# Out:
# ['agents', 'run.py', 'utils.py', '__init__.py', '__pycache__']

# %%
os.listdir("src")
# Out:
# ['agents', 'run.py', 'utils.py', '__init__.py', '__pycache__']

# %%
os.listdir("src")
# Out:
# ['agents', 'run.py', 'utils.py', '__init__.py', '__pycache__']

# %%
# !python -m src.run "Analyze ROAS drop in last 14 days"
# Out:
# Planning for query: analyze roas drop in last 14 days
# C:\Users\ALI MUHAMMAD\Desktop\kasparro_project\src\run.py:40: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   run_id = datetime.utcnow().strftime("%Y%m%dT%H%M%SZ")
# DONE!
# Report saved to: reports\report.md

# %%
# !python src/run.py "Analyze ROAS drop in last 14 days"
# Out:
# Planning for query: analyze roas drop in last 14 days
# DONE!
# Report saved to: reports\report.md
# C:\Users\ALI MUHAMMAD\Desktop\kasparro_project\src\run.py:40: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   run_id = datetime.utcnow().strftime("%Y%m%dT%H%M%SZ")

# %%
# !python src/run.py "Generate recommendations to improve ROAS for last quarter"
# Out:
# Planning for query: generate recommendations to improve roas for last quarter
# DONE!
# Report saved to: reports\report.md
# C:\Users\ALI MUHAMMAD\Desktop\kasparro_project\src\run.py:40: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   run_id = datetime.utcnow().strftime("%Y%m%dT%H%M%SZ")
