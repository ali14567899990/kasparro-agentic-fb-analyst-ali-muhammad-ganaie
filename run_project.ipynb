# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ALI MUHAMMAD\\Desktop\\kasparro-agentic-fb-analyst-ali-muhammad-ganaie'

# %%
# !python -m src.run "Analyze ROAS drop in last 14 days"
# Out:
# DONE!
# Report saved to: reports\report.md
# C:\Users\ALI MUHAMMAD\Desktop\kasparro-agentic-fb-analyst-ali-muhammad-ganaie\src\run.py:40: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   run_id = datetime.utcnow().strftime("%Y%m%dT%H%M%SZ")
# 2025-11-29 15:06:19,867 | PlannerAgent | INFO | Planning tasks for query: analyze roas drop in last 14 days
# 2025-11-29 15:06:19,867 | PlannerAgent | INFO | Planned tasks: ['analyze_roas']
# 2025-11-29 15:06:19,867 | DataAgent | INFO | Loading data from: data/synthetic_fb_ads_undergarments.csv
# 2025-11-29 15:06:19,882 | DataAgent | INFO | Schema drift report: {'missing_fields': [], 'unexpected_fields': ['adset_name', 'creative_type', 'audience_type', 'creative_message', 'purchases', 'ctr', 'roas', 'country', 'platform'], 'schema_version': '1.0.0'}
# ...

# %%
# !python -m src.run "Analyze CTR drop in last 7 days"
# Out:
# DONE!
# Report saved to: reports\report.md
# C:\Users\ALI MUHAMMAD\Desktop\kasparro-agentic-fb-analyst-ali-muhammad-ganaie\src\run.py:40: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   run_id = datetime.utcnow().strftime("%Y%m%dT%H%M%SZ")
# 2025-11-29 15:03:09,659 | PlannerAgent | INFO | Planning tasks for query: analyze ctr drop in last 7 days
# 2025-11-29 15:03:09,659 | PlannerAgent | INFO | Planned tasks: ['analyze_ctr']
# 2025-11-29 15:03:09,659 | DataAgent | INFO | Loading data from: data/synthetic_fb_ads_undergarments.csv
# 2025-11-29 15:03:09,672 | DataAgent | INFO | Schema drift report: {'missing_fields': [], 'unexpected_fields': ['ctr', 'audience_type', 'creative_message', 'country', 'roas', 'adset_name', 'purchases', 'platform', 'creative_type'], 'schema_version': '1.0.0'}
# ...
